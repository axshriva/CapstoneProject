# %%
import pandas as pd
import matplotlib.pyplot as plt
Members = pd.read_csv('members.csv', index_col = 'registration_init_time', parse_dates = True)
Members.head()
# Out:
#                                                                 msno  city  \
# registration_init_time
# 2011-09-11              Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1
# 2011-09-14              +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1
# 2011-09-15              cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1
# 2011-09-15              9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1
# 2011-09-15              WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6
#
#                         bd  gender  registered_via
# registration_init_time
# 2011-09-11               0     NaN              11
# 2011-09-14               0     NaN               7
# 2011-09-15               0     NaN              11
# 2011-09-15               0     NaN              11
# 2011-09-15              32  female               9

# %%
Members.shape
# Out:
# (1048575, 5)

# %%
Members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1048575 entries, 2011-09-11 to 2014-11-02
# Data columns (total 5 columns):
# msno              1048575 non-null object
# city              1048575 non-null int64
# bd                1048575 non-null int64
# gender            408814 non-null object
# registered_via    1048575 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 48.0+ MB

# %%
Members.gender.value_counts(dropna=False)
# Out:
# NaN       639761
# male      208347
# female    200467
# Name: gender, dtype: int64

# %%
Members.msno.value_counts(dropna=False)
# Out:
# Eu080C0t7IHYIleh+kS5S4L0+ixGhQJ4hMqxB6uiM2E=    1
# AktHcb5NzqAG/E/8yR/JOhphpU45fzj7ER6dqUIV/o4=    1
# ydQhqUdc2nkUU01ZD4h9p2buO9UmD7OZh5p9NegTvik=    1
# TaVSLR9SZe3tzNZcZBwHhR3zeQv3l8b8tBM1Wc79+eE=    1
# E7iwjQep3eUsIriKiLztUWxQ+rryXMAroxTd7tyQrrs=    1
# tugCz/Aj5nUEwrKqtK46Myhev1s/MYxvEXpwU2hyBRM=    1
# IDUguEYCeo+Pw4rdtBFAsI28Cu51FaLx3/tuUZlHeXM=    1
# tERV9iHe6XH3KzU4U/NZIKqbwmM1ZkiJkF06WgJTh3o=    1
# L6zQQgpWOBtneP+9zzRGID3ybCqd6r+21nLSAHCujc0=    1
# Lt2VJTrtHS9ZIBv7kFv6fpRbj/F94bO/jYXAXkxdw1g=    1
# 7pk9yHu29rD2H5+XZKgm9Orrj2q+wOCAiAjN8BSF/uA=    1
# KdN+PUhZ0bZY6RXksVsgCswldjxK/SsCnrRbingpE6c=    1
# i/wTUaw7O07pImDTEQ6Rn0OcY2YnBPyOrlmvRSiWENA=    1
# BxPA5zComYFDvUKufmtcKHdUOdHUA3tZNuhwEPtgBIY=    1
# wclns8doN7AorjGsZlQOVQqAnupQEEVwXG3FCC5JvVQ=    1
# u9OeMiX3Vm5AWOzKVKoxkL8VWdSeYWSBOyHQ6YPmk8I=    1
# EdjpTaI8f3qCJOh6/Uza76hYQgpTt+3g77MDj7BehiE=    1
# b47C8eBzFuAiH/jEizQNw12bub/QykbH1vFwhuvAcNA=    1
# M48sQOCsg/Jk1tDGDKw6SvrhagwlOegUqRgZLyxZosU=    1
# ...

# %%
Members.columns = ['Msno', 'City', 'Age', 'Gender', 'Registred_Via']

# %%
from datetime import datetime

# %%
# Data Exploration
# Are the IDs Unique and 
Members['Msno'].nunique()-Members['Msno'].count()
# Out:
# 0

# %%
#Are the IDs not null
Members['Msno'].isnull().count()
# NO null or duplicate values
# Out:
# 1048575

# %%
# Check the city data out
Members['City'].isnull().count()
# Out:
# 1048575

# %%
City = Members.City.value_counts()
#City1['City Name']=Members['City']
City= City.to_frame().reset_index()
City.head()
City.reset_index()
City.columns = [['City Name', 'City Total']]
City.head()
# Out:
#   City Name City Total
# 0         1     684530
# 1         5      67515
# 2        13      66338
# 3         4      44520
# 4        22      38133

# %%
City.columns
# Out:
# MultiIndex(levels=[['City Name', 'City Total']],
#            labels=[[0, 1]])

# %%
#Check for outliers and values in registred via file
k =Members.Registred_Via.value_counts()

# %%
type(k)
k= k.to_frame().reset_index()
k.columns
# Out:
# Index(['index', 'Registred_Via'], dtype='object')

# %%
k.plot('index', 'Registred_Via', 'bar')

# %%
#Check for outliers and values in registred via file
j =Members.City.value_counts()

# %%
type(k)
j= j.to_frame().reset_index()
j.columns
# Out:
# Index(['index', 'City'], dtype='object')

# %%
j.plot('index', 'City', 'bar')

plt.title('Total count for each City')
plt.xlabel('City Name')
plt.ylabel('Total Count')
# Out:
# Text(0,0.5,'Total Count')

# %%
Time = Members.resample('Q')

# %%
Time
# Out:
# DatetimeIndexResampler [freq=<QuarterEnd: startingMonth=12>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
Members.head()
# Out:
#                                                                 Msno  City  \
# registration_init_time
# 2011-09-11              Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1
# 2011-09-14              +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1
# 2011-09-15              cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1
# 2011-09-15              9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1
# 2011-09-15              WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6
#
#                         Age  Gender  Registred_Via
# registration_init_time
# 2011-09-11                0     NaN             11
# 2011-09-14                0     NaN              7
# 2011-09-15                0     NaN             11
# 2011-09-15                0     NaN             11
# 2011-09-15               32  female              9

# %%
Reg = Members['Msno']

# %%
type(Reg)
# Out:
# pandas.core.series.Series

# %%
Reg.head()
# Out:
# registration_init_time
# 2011-09-11    Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=
# 2011-09-14    +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=
# 2011-09-15    cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=
# 2011-09-15    9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=
# 2011-09-15    WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=
# Name: Msno, dtype: object

# %%
Trn = pd.read_csv('transactions_v2.csv')

# %%
Trn.head()
# Out:
#                                            msno  payment_method_id  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#    transaction_date  membership_expire_date  is_cancel
# 0          20170131                20170504          0
# ...

# %%
Trn.payment_method_id.value_counts(dropna=False)
# Out:
# 41    696696
# 39    137120
# 38    115875
# 32    100982
# 36     90844
# 40     82747
# 37     40414
# 34     31099
# 29     24957
# 30     21182
# 33     16715
# 31     11597
# 35      9759
# 22      9563
# 15      7705
# 20      6651
# 13      5050
# 28      3452
# 12      2858
# 23      2719
# 17      2532
# 19      2136
# 27      2074
# 21      1846
# 16      1842
# 18       714
# 14       672
# 26       668
# 6        186
# 8        179
# 11        79
# 3         42
# 10        40
# 25         5
# 24         4
# 2          4
# 5          1
# Name: payment_method_id, dtype: int64

# %%
Members.Gender.value_counts(dropna=False)
# Out:
# NaN       639761
# male      208347
# female    200467
# Name: Gender, dtype: int64

# %%
Trn.payment_plan_days.value_counts(dropna=False)
# Out:
# 30     1217998
# 410      82097
# 195      28568
# 180      23900
# 90       19130
# 7        12168
# 395       9753
# 360       4658
# 100       4098
# 365       3838
# 120       3612
# 240       3440
# 415       3298
# 60        3134
# 200       3108
# 0         2218
# 400       1817
# 450       1762
# 270        997
# 1          676
# 10         416
# 14          82
# 70          49
# 80          43
# 45          41
# 230         35
# 35          29
# 110         20
# 21          11
# 3            9
# 31           4
# Name: payment_plan_days, dtype: int64

# %%
Trn.plan_list_price.value_counts(dropna=False)
# Out:
# 149     594395
# 99      407750
# 180     115660
# 1788     83963
# 129      52986
# 100      43873
# 894      29677
# 0        18413
# 536      18335
# 1599     14727
# 477       7891
# 1200      7603
# 298       6049
# 300       4782
# 447       4041
# 480       3857
# 1299      3052
# 930       2796
# 600       2729
# 150       2144
# 699       2126
# 799       1434
# 119        527
# 35         322
# 1000       303
# 120        275
# 450        264
# 500        241
# 1399       137
# 2000       130
# 134        109
# 596         66
# 210         65
# 350         49
# 126         46
# 400         43
# 1150        35
# 1           25
# 1260        25
# 131         24
# 105         11
# 70          11
# 1300         6
# 143          4
# 265          4
# 50           2
# 30           1
# 15           1
# Name: plan_list_price, dtype: int64

# %%
Trn.actual_amount_paid.value_counts()
# Out:
# 149     589691
# 99      408561
# 180     112512
# 1788     83980
# 129      53410
# 100      43893
# 894      29674
# 0        21448
# 536      18335
# 1599     14719
# 477       7891
# 1200      7608
# 298       6049
# 300       4782
# 119       4103
# 447       4047
# 480       3857
# 1299      3052
# 930       2796
# 600       2729
# 150       2143
# 699       2126
# 799       1434
# 35         322
# 1000       303
# 450        264
# 500        241
# 120        225
# 1399       137
# 2000       130
# 134        109
# 596         81
# 210         65
# 350         49
# 127         46
# 400         43
# 1150        35
# 1           25
# 1260        25
# 131         24
# 70          11
# 105         11
# 1300         6
# 265          4
# 143          4
# 50           2
# 897          1
# 1780         1
# 984          1
# 30           1
# 15           1
# 1778         1
# 849          1
# Name: actual_amount_paid, dtype: int64

# %%
Trn.is_auto_renew.value_counts(dropna=False)
# Out:
# 1    1123775
# 0     307234
# Name: is_auto_renew, dtype: int64

# %%
Trn.is_cancel.value_counts(dropna=False)
# Out:
# 0    1395876
# 1      35133
# Name: is_cancel, dtype: int64

# %%
MemberTxn = pd.merge(Members, Trn, left_on='Msno', right_on='msno')

# %%
MemberTxn.reset_index()
# Out:
#          index                                          Msno  City  Age  \
# 0            0  +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1    0
# 1            1  WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6   32
# 2            2  yLkV2gbZ4GLFwqTOXLVHz0VGrMYcgBGgKZ3kj9RiYu8=     4   30
# 3            3  yLkV2gbZ4GLFwqTOXLVHz0VGrMYcgBGgKZ3kj9RiYu8=     4   30
# 4            4  WH5Jq4mgtfUFXh2yz+HrcTXKS4Oess4k4W3qKolAeb0=     5   34
# 5            5  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13   63
# 6            6  OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1    0
# 7            7  4De1jAxNRABoyRBDZ82U0yEmzYkqeOugRGVNIf92Xb8=     4   28
# 8            8  fOpj0ApSXk1NVODvC5db5Tvm/1G6exXxgTiCwTqvQn0=    13   31
# 9            9  glvtik6LgKzz/VHI8f7dAAHW4iqU8azER8mEsImDe78=     9   21
# 10          10  GqYHRxlZChiZvB1uzR410wcQzuxqZNZci4AzOTzkAao=     5   27
# 11          11  GqYHRxlZChiZvB1uzR410wcQzuxqZNZci4AzOTzkAao=     5   27
# ...

# %%
type(MemberTxn)
# Out:
# pandas.core.frame.DataFrame

# %%
MemberTxn.Msno.value_counts()
# Out:
# 5ty4nZkq54z93wQtBN7RHVYj8rNghBDCVBH+3xmxf0I=    172
# OGKDrZQDB3yewZhoSd5qqvmG5A1GcNTYMexO95NlH+g=    148
# IO+048XfFoL7X++ftIyb/zFKwNUUAkKaZLWrvg48TXA=     89
# Cb4XS2qU2qnJ5f5iUaWIGOnVf1QWDtq1gYBZ9CRs8yU=     63
# w46D27PaHRxE6kJhECr6QNk+4ELIzDyBRTZQCe019m0=     48
# GUlOynwcbchLoK1DjZ9pMqC3HiK1BOGDV3g4xuUeNA0=     48
# xH/K9MtJtoUyVwWj8Iy1hKAPuhothpmGOLfcJphXQkA=     45
# N+h+p3YxIPMkqo8JA+pLhOX+j6CH3w82/GnbNTNTnY0=     45
# mFE7bNK4EqZJ7I5KEa0jsii9LaHIW0elj4xVp64K9R8=     45
# LVnR14yJVs60jopBQJHdPGoamCV/dIgFR+uPFP8HsbE=     41
# 7zVj7hq7W8ivp72I4c4n4ZPu2sK48GQZsBqvbHkYtYo=     39
# rYjoozKjJf44sU2uXn69Vi6qwCoGtPLQJlbVXZybxeI=     39
# lDBriVxRAkkNqcgs7ZrPLzcYp5ObxTKLvQpBL2HB0Xg=     39
# suDpWBfL1/14bDFOnzv4Jqe/sOl/3xxuTAXSiZH150E=     39
# 2oWV57kXfFNonQFbAN7iGxbBdt+doRgkCBzl0x1+uRg=     38
# Obn2IRgrD0rNBNJQr9abThU0JVmxcSv/r85evEUZSqU=     38
# zDgMEKP50lTDdNPKRbujG3KQVU6YJTlZ/+y7tPeslU4=     38
# Y/oXcJuj2oVgZEIbEWXT0H1rEnfTP26pTpvydYG6Srs=     37
# ...

# %%
datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-0b768266a4e6> in <module>()
# ----> 1 datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')
#
# NameError: name 'datetime_str' is not defined

# %%
Trn.head()
# Out:
#                                            msno  payment_method_id  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#    transaction_date  membership_expire_date  is_cancel
# 0          20170131                20170504          0
# ...

# %%
Logs = pd.read_csv('user_logs_v2.csv')

# %%
Logs.head()
# Out:
#                                            msno      date  num_25  num_50  \
# 0  u9E91QDTvHLq6NXjEaWv8u4QIqhrHk72kE+w31Gnhdg=  20170331       8       4
# 1  nTeWW/eOZA/UHKdD5L7DEqKKFTjaAj3ALLPoAWsU8n0=  20170330       2       2
# 2  2UqkWXwZbIjs03dHLU9KHJNNEvEkZVzm69f3jCS+uLI=  20170331      52       3
# 3  ycwLc+m2O0a85jSLALtr941AaZt9ai8Qwlg9n0Nql5U=  20170331     176       4
# 4  EGcbTofOSOkMmQyN1NMLxHEXJ1yV3t/JdhGwQ9wXjnI=  20170331       2       1
#
#    num_75  num_985  num_100  num_unq  total_secs
# 0       0        1       21       18    6309.273
# 1       1        0        9       11    2390.699
# 2       5        3       84      110   23203.337
# 3       2        2       19      191    7100.454
# 4       0        1      112       93   28401.558

# %%
Logs.msno.value_counts(dropna=False)
# Out:
# 58wEuqxUUsYaoNsYxcgWR3ukmmSBDPdDnTNqBjW5m9A=    31
# lA+PhQlLyZtqJKmjLfDhSN1DCUksq4slpC4AK914u04=    31
# YeQc5b0/TyEo3CPefO5vJgwEWiI+ycdo1A9lLqo8i2A=    31
# VRFv1EtovXjY4JH3dlK30ohdmoaYl4LTselAx0XKaB8=    31
# J9vcsyVupHYBDij/JDYzhrH+S9J3Vzq915t1rkzAN1k=    31
# 0azjJbLEWKbIEnl6mFIx8XHasf+i6l34k8ePOppok98=    31
# rdbEB7gNRJDCQhNJlBXebmQQJ8FkwqhLrbayLMTa5nA=    31
# EICIJiudSO7ZwBPEs/KyZ4Y9TIPk8woUhmOCs9PwL3w=    31
# zFmZSK5aJlIFeCkRmJdTMiFarYdDQr7KeEQS50YAu0A=    31
# r56zFzBoyM4yc0Izya2R3W6Eiebfkik/sar7P/HOqp8=    31
# 8FElsBeSA39YeZAge3zCWJClriWuOieeQscZA8sPgNs=    31
# Fx2ZL4cdzlaxn1WOgqLSPevk0zNqAwidku68yb51Ezw=    31
# zAEjHmfu7rTPcHfYkBzA4liPdfpJcNx/M5HwJDoZ/PY=    31
# G/NuQenhu8/nLlSX6btksYdz9/FO7zNTv7+OnYF3ZME=    31
# 6sDCRsl8hz1opKbzgt1y98VEyS+lHkXN02QJTyyVOxE=    31
# Rci5xb3KFaydPqiu8Giih6EG0GQqM3+6b+b2KbTcitg=    31
# wQdPABa5TqRMh6JWHNqpLmn4d2rvqDsf2/4Devm6TrU=    31
# HdZBSYA/MYIDS4oHAO1gUKOwTUdYOdM+0zAHrLdj7Nc=    31
# ...

# %%
plt.plot
